# %%
#Stella high school grade analysis (freshman year) @Sesi Internacional 
#this was created to observe her performance as well as test some hyphothesis
#grades are analyzed every quarter

# %%
#import numpy
import numpy as np

Quarters = ['Quarter1', 'Quarter2', 'Quarter3', 'FinalGrade']   #quarters list
Quartersdict = {'Quarter1':0, 'Quarter2':1, 'Quarter3':2, 'FinalGrade':3}
Subjects = ['Química',
'Física',
'Matemática',
'Biologia',
'L.E.M. Inglês',
'Arte',
'Educação Física',
'História',
'Geografia',
'Filosofia',
'Sociologia',
'Ciências Aplicadas',
'Projetos de Aprendizagem',
'Produção Textual',
'Língua Portuguesa',
'Arte I',
'História I',
'Geografia I',
'Oficinas Tecnológicas',
'Produção Textual II',
'Educação Física I',
'Ética e Cidadania',
'Ciências da Natureza'] #subjects list
Subjectsdict = {'Química':0,
'Física':1,
'Matemática':2,
'Biologia':3,
'L.E.M. Inglês':4,
'Arte':5,
'Educação Física':6,
'História':7,
'Geografia':8,
'Filosofia':9,
'Sociologia':10,
'Ciências Aplicadas':11,
'Projetos de Aprendizagem':12,
'Produção Textual':13,
'Língua Portuguesa':14,
'Arte I':15,
'História I':16,
'Geografia I':17,
'Oficinas Tecnológicas':18,
'Produção Textual II':19,
'Educação Física I':20,
'Ética e Cidadania':21,
'Ciências da Natureza':22}

# %%
Quarter1Grades = [93,
90,
99,
90,
100,
97,
98,
86,
84,
81,
86,
92,
94,
89,
98,
97,
86,
84,
92,
97,
98,
86,
95]
Quarter2Grades = [75,
78,
81,
80,
97,
83,
86,
97,
93,
73,
90,
79,
60,
79,
77,
100,
97,
93,
78,
87,
86,
90,
79]
Quarter3Grades = [80,
92,
89,
93,
99,
96,
100,
91,
92,
85,
94,
83,
46,
97,
97,
88,
91,
92,
90,
100,
100,
85,
100]
FinalGrade = [83,
87,
90,
88,
99,
92,
95,
91,
90,
80,
90,
85,
70,
88,
91,
95,
91,
90,
87,
95,
95,
87,
91]

# %%
QuimicaGr = [93,75,80,83] #these are the grades list per subject
FisicaGr = [90,78,92,87]
MatematicaGr = [99,81,89,90]
BiologiaGr = [90,80,93,88]
LEMInglesGr = [100,97,99,99]
ArteGr = [97,83,96,92]
EducacaoFisicaGr = [98,86,100,95]
HistoriaGr = [86,97,91,91]
GeografiaGr = [84,93,92,90]
FilosofiaGr = [81,73,85,80]
SociologiaGr = [86,90,94,90]
CienciasAplicadasGr = [92,79,83,85]
ProjetosDeAprendizagemGr = [94,60,46,70]
ProducaoTextualGr = [89,79,97,88]
LinguaPortuguesaGr = [98,77,97,91]
ArteIGr = [97,100,88,95]
HistoriaIGr = [86,97,91,91]
GeografiaIGr = [84,93,92,90]
OficinasTecnologicasGr = [92,78,90,87]
ProducaoTextualIIGr = [97,87,100,95]
EducacaoFisicaIGr = [98,86,100,95]
EticaECidadaniaGr = [86,90,85,87]
CienciasDaNaturezaGr = [95,79,100,91]

# %%
#The matrix
Gradespersubject = np.array([QuimicaGr, FisicaGr, MatematicaGr, BiologiaGr, LEMInglesGr, ArteGr, EducacaoFisicaGr, HistoriaGr, GeografiaGr, FilosofiaGr, SociologiaGr,CienciasAplicadasGr,ProjetosDeAprendizagemGr,ProducaoTextualGr, LinguaPortuguesaGr,ArteIGr,HistoriaIGr,GeografiaIGr,OficinasTecnologicasGr,ProducaoTextualIIGr,EducacaoFisicaIGr,EticaECidadaniaGr,CienciasDaNaturezaGr])

# %%
Gradespersubject
# Out:
# array([[ 93,  75,  80,  83],
#        [ 90,  78,  92,  87],
#        [ 99,  81,  89,  90],
#        [ 90,  80,  93,  88],
#        [100,  97,  99,  99],
#        [ 97,  83,  96,  92],
#        [ 98,  86, 100,  95],
#        [ 86,  97,  91,  91],
#        [ 84,  93,  92,  90],
#        [ 81,  73,  85,  80],
#        [ 86,  90,  94,  90],
#        [ 92,  79,  83,  85],
#        [ 94,  60,  46,  70],
#        [ 89,  79,  97,  88],
#        [ 98,  77,  97,  91],
#        [ 97, 100,  88,  95],
#        [ 86,  97,  91,  91],
#        [ 84,  93,  92,  90],
#        [ 92,  78,  90,  87],
#        [ 97,  87, 100,  95],
#        [ 98,  86, 100,  95],
#        [ 86,  90,  85,  87],
#        [ 95,  79, 100,  91]])

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline 
plt.rcParams['figure.figsize']=8,4

# %%
plt.plot(Gradespersubject[0], c='Blue', ls='--', marker='s', ms=7, label= Subjects[0]) #Pdict[0] == Quimica
plt.plot(Gradespersubject[1], c='Red', ls='--', marker='o', ms=7, label= Subjects[1])  #Pdict[1] == Fisica
plt.plot(Gradespersubject[2], c='Green', ls='--', marker='v', ms=7, label=Subjects[2]) #Pdict[2] == Matematica
plt.plot(Gradespersubject[3], c='Gray', ls='--', marker='v', ms=7, label=Subjects[3])  #Pdict[3] == Biologia
plt.plot(Gradespersubject[4], c='Purple', ls='--', marker='v', ms=7, label=Subjects[4])#Pdict[4] == LEM Ingles
plt.plot(Gradespersubject[5], c='Magenta', ls='--', marker='v', ms=7, label=Subjects[5]) #Pdict[5] == Arte
plt.legend()
plt.xticks(list(range(0,10)), Quarters, rotation='vertical')
plt.show()

# %%
#tendency #1 2nd quarter Stella's grades were down due to group issues;

# %%
vis1 = sns.distplot(Gradespersubject, bins=50)

# %%
#tendency #2 Stella's grades were mostly above mean

# %%
vis3 = sns.boxplot(data=Gradespersubject)

# %%
#tendency #3 Stella's grades decreased from q1 top q2 however they were still above average

# %%
vis4 = sns.boxplot(data=[QuimicaGr, FisicaGr, BiologiaGr, MatematicaGr])  #this was simply a test

# %%
meanQuimica = np.mean(QuimicaGr)
print('média de Quimica: ',meanQuimica)
# Out:
# média de Quimica:  82.75

# %%
media = np.mean(Quarter1Grades)

# %%
print(media)
# Out:
# 91.82608695652173

# %%
import pandas as pd
notasstella = pd.DataFrame()

# %%
notasstella
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
COLUNAS = [
    'Subject',
    'Quarter1Grades',
    'Quarter2Grades',
    'Quarter3Grades',
    'FinalGrades'
]
notasstella = pd.DataFrame(columns=COLUNAS)

# %%
notasstella
# Out:
# Empty DataFrame
# Columns: [Subject, Quarter1Grades, Quarter2Grades, Quarter3Grades, FinalGrades]
# Index: []

# %%
Subjects[0]
# Out:
# 'Química'

# %%
#creating a dataframe for all the grades
#which would make the plots easier


obj = {'Subject': ['Química',
'Física',
'Matemática',
'Biologia',
'L.E.M. Inglês',
'Arte',
'Educação Física',
'História',
'Geografia',
'Filosofia',
'Sociologia',
'Ciências Aplicadas',
'Projetos de Aprendizagem',
'Produção Textual',
'Língua Portuguesa',
'Arte I',
'História I',
'Geografia I',
'Oficinas Tecnológicas',
'Produção Textual II',
'Educação Física I',
'Ética e Cidadania',
'Ciências da Natureza'], 'Quarter1Grades': [93,
90,
99,
90,
100,
97,
98,
86,
84,
81,
86,
92,
94,
89,
98,
97,
86,
84,
92,
97,
98,
86,
95], 'Quarter2Grades': [75,
78,
81,
80,
97,
83,
86,
97,
93,
73,
90,
79,
60,
79,
77,
100,
97,
93,
78,
87,
86,
90,
79], 'Quarter3Grades': [80,
92,
89,
93,
99,
96,
100,
91,
92,
85,
94,
83,
46,
97,
97,
88,
91,
92,
90,
100,
100,
85,
100], 'FinalGrades': [83,
87,
90,
88,
99,
92,
95,
91,
90,
80,
90,
85,
70,
88,
91,
95,
91,
90,
87,
95,
95,
87,
91]}
notasstella = pd.DataFrame(data=obj)

# %%
notasstella
# Out:
#                      Subject  Quarter1Grades  Quarter2Grades  Quarter3Grades  \
# 0                    Química              93              75              80
# 1                     Física              90              78              92
# 2                 Matemática              99              81              89
# 3                   Biologia              90              80              93
# 4              L.E.M. Inglês             100              97              99
# 5                       Arte              97              83              96
# 6            Educação Física              98              86             100
# 7                   História              86              97              91
# 8                  Geografia              84              93              92
# 9                  Filosofia              81              73              85
# 10                Sociologia              86              90              94
# ...

# %%
notasstella.describe()
# Out:
#        Quarter1Grades  Quarter2Grades  Quarter3Grades  FinalGrades
# count       23.000000        23.00000       23.000000    23.000000
# mean        91.826087        84.26087       90.434783    89.130435
# std          5.718011         9.56422       11.260656     5.956695
# min         81.000000        60.00000       46.000000    70.000000
# 25%         86.000000        78.50000       88.500000    87.000000
# 50%         92.000000        83.00000       92.000000    90.000000
# 75%         97.000000        91.50000       97.000000    91.500000
# max        100.000000       100.00000      100.000000    99.000000

# %%
notasstella
# Out:
#                      Subject  Quarter1Grades  Quarter2Grades  Quarter3Grades  \
# 0                    Química              93              75              80
# 1                     Física              90              78              92
# 2                 Matemática              99              81              89
# 3                   Biologia              90              80              93
# 4              L.E.M. Inglês             100              97              99
# 5                       Arte              97              83              96
# 6            Educação Física              98              86             100
# 7                   História              86              97              91
# 8                  Geografia              84              93              92
# 9                  Filosofia              81              73              85
# 10                Sociologia              86              90              94
# ...

# %%
notasstella[1:4]
# Out:
#       Subject  Quarter1Grades  Quarter2Grades  Quarter3Grades  FinalGrades
# 1      Física              90              78              92           87
# 2  Matemática              99              81              89           90
# 3    Biologia              90              80              93           88

# %%
notasview = notasstella[['Quarter1Grades', 'Quarter2Grades', 'Quarter3Grades', 'FinalGrades']] 
#making a view only with the grades

# %%
vis4 = sns.boxplot(data=[notasview])

# %%
notasview.describe()
# Out:
#        Quarter1Grades  Quarter2Grades  Quarter3Grades  FinalGrades
# count       23.000000        23.00000       23.000000    23.000000
# mean        91.826087        84.26087       90.434783    89.130435
# std          5.718011         9.56422       11.260656     5.956695
# min         81.000000        60.00000       46.000000    70.000000
# 25%         86.000000        78.50000       88.500000    87.000000
# 50%         92.000000        83.00000       92.000000    90.000000
# 75%         97.000000        91.50000       97.000000    91.500000
# max        100.000000       100.00000      100.000000    99.000000

# %%
vis1 = sns.distplot(notasview, bins=50)

# %%
notasstella.sort_values("FinalGrades", ascending=False).head(5) #sorting Stella's 5 top final grades
# Out:
#                 Subject  Quarter1Grades  Quarter2Grades  Quarter3Grades  \
# 4         L.E.M. Inglês             100              97              99
# 6       Educação Física              98              86             100
# 19  Produção Textual II              97              87             100
# 20    Educação Física I              98              86             100
# 15               Arte I              97             100              88
#
#     FinalGrades
# 4            99
# 6            95
# 19           95
# 20           95
# 15           95

# %%
#assumption1: would these Subjects be Stella's favorites? :-)

# %%
notasstella.sort_values("FinalGrades", ascending=True).head(5) #sorting Stella's 5 bottom final grades
# Out:
#                      Subject  Quarter1Grades  Quarter2Grades  Quarter3Grades  \
# 12  Projetos de Aprendizagem              94              60              46
# 9                  Filosofia              81              73              85
# 0                    Química              93              75              80
# 11        Ciências Aplicadas              92              79              83
# 18     Oficinas Tecnológicas              92              78              90
#
#     FinalGrades
# 12           70
# 9            80
# 0            83
# 11           85
# 18           87

# %%
#assumption2: would these be her least favorites?

# %%
notasstella.describe()
# Out:
#        Quarter1Grades  Quarter2Grades  Quarter3Grades  FinalGrades
# count       23.000000        23.00000       23.000000    23.000000
# mean        91.826087        84.26087       90.434783    89.130435
# std          5.718011         9.56422       11.260656     5.956695
# min         81.000000        60.00000       46.000000    70.000000
# 25%         86.000000        78.50000       88.500000    87.000000
# 50%         92.000000        83.00000       92.000000    90.000000
# 75%         97.000000        91.50000       97.000000    91.500000
# max        100.000000       100.00000      100.000000    99.000000

# %%
#this is a query example where I look for grades below the average of 70 according to school rules
notasstella.query("Quarter1Grades<=70" and "Quarter2Grades<=70" and "Quarter3Grades<=70")
# Out:
#                      Subject  Quarter1Grades  Quarter2Grades  Quarter3Grades  \
# 12  Projetos de Aprendizagem              94              60              46
#
#     FinalGrades
# 12           70

# %%
#question: why did this happen?

# %%
#this graph shows better Stella's grade distribution
import seaborn as sns
sns.set_style("whitegrid")
notasstella["FinalGrades"].plot(kind='hist')

# %%
sns.scatterplot(data=notasstella, x="Subject", y="Quarter1Grades")
sns.scatterplot(data=notasstella, x="Subject", y="Quarter2Grades")
sns.scatterplot(data=notasstella, x="Subject", y="Quarter3Grades")
plt.xticks(list(range(0,23)), Subjectsdict, rotation='vertical')
# Out:
# ([<matplotlib.axis.XTick at 0x1a1f46fe10>,
# ...
#  <a list of 23 Text xticklabel objects>)
