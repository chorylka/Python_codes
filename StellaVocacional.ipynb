# %%
MundoVestibular = list ([
"Arquitetura",
"Artes Cênicas",
"Artes plásticas",
"Astronomia",
"Ciências Biológicas (Biologia)",
"Cinema",
"Engenharia Mecânica",
"Esporte",
"Filosofia",
"Jornalismo",
"Matemática",
"Publicidade",
"Rádio e TV",
"Turismo",
"Veterinária",
"Educação Física",
"Meteorologia",
"Oceanografia",
"Engenharia Ambiental",
"Engenharia Florestal",
"Arqueologia"])

# %%
QueroBolsa = list (["Gestão Financeira",
"Marketing",
"Administração",
"Direito",
"Pedagogia", 
"Psicologia",
"None",
"None",
"None","None","None","None","None","None","None","None","None","None","None","None","None"])

# %%
Neora = list (["Gestão pública",
"Administração e Organização de eventos",
"Gestão hospitalar",
"Jornalismo",
"Administração",  
"Gastronomia",
"None","None","None","None","None","None","None","None","None","None","None","None","None","None","None"])

# %%
G1 = list (["Direito",
"Astronomia",
"TI",
"Economia",
"Administração",
"Arquitetura",
"Biomedicina",
"Design de games",
"Filosofia",
"Ciências Gerais",
"None","None","None","None","None","None","None","None","None","None","None"])

# %%
FundacaoEstudar = list (["Coaching",
"Nutrição",
"Biblioteconomia",
"Odontologia",
"Fonoaudiologia",
"RH",
"Medicina",
"Serviço Social",
"Psiquiatria",
"Turismo",
"Podologia",
"Psicologia",
"Terapia Ocupacional",
"Educação Física",
"Pedagogia",
"Direito",
"Professor",
"None","None","None","None"])

# %%
TesteVocacionalOnline = list (["Biblioteconomia",
"Ciências Sociais",
"Educação Física",
"Geografia",
"História",
"Letras",
"Matemática",
"Pedagogia",
"Psicologia",
"None","None","None","None","None","None","None","None","None","None","None","None"])

# %%
TesteVocacionalOrg = list (["TI",
"Astronomia",
"Design",
"Economia",
"Antropologia",
"Engenharia",
"Arquitetura",
"None","None","None","None","None","None","None","None","None","None","None","None","None","None"])

# %%
UNASP = list (["Ciências biológicas",
"Rádio e TV",
"Educação Física",
"Enfermagem",
"Fisioterapia",
"RH",
"História",
"Letras",
"Nutrição",
"Pedagogia",
"Teologia",
"Psicologia",
"None","None","None","None","None","None","None","None","None"])

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline


stella_vocacional = pd.DataFrame({'MundoVestibular': np.array(MundoVestibular),
                                  'QueroBolsa': np.array(QueroBolsa),
                                  'Neora': np.array(Neora),
                                  'G1': np.array(G1),
                                  'FundacaEstudar': np.array(FundacaoEstudar),
                                  'TesteVocacionalOnline': np.array(TesteVocacionalOnline),
                                  'TesteVocacionalOrg': np.array(TesteVocacionalOrg),
                                  'UNASP': np.array(UNASP),
                              
    })

# %%
stella_vocacional
# Out:
#                    MundoVestibular         QueroBolsa  \
# 0                      Arquitetura  Gestão Financeira
# 1                    Artes Cênicas          Marketing
# 2                  Artes plásticas      Administração
# 3                       Astronomia            Direito
# 4   Ciências Biológicas (Biologia)          Pedagogia
# 5                           Cinema         Psicologia
# 6              Engenharia Mecânica               None
# 7                          Esporte               None
# 8                        Filosofia               None
# 9                       Jornalismo               None
# 10                      Matemática               None
# 11                     Publicidade               None
# 12                      Rádio e TV               None
# 13                         Turismo               None
# 14                     Veterinária               None
# 15                 Educação Física               None
# ...

# %%
stella_vocacional.head()
# Out:
#                   MundoVestibular         QueroBolsa  \
# 0                     Arquitetura  Gestão Financeira
# 1                   Artes Cênicas          Marketing
# 2                 Artes plásticas      Administração
# 3                      Astronomia            Direito
# 4  Ciências Biológicas (Biologia)          Pedagogia
#
#                                     Neora             G1   FundacaEstudar  \
# 0                          Gestão pública        Direito         Coaching
# 1  Administração e Organização de eventos     Astronomia         Nutrição
# 2                       Gestão hospitalar             TI  Biblioteconomia
# 3                              Jornalismo       Economia      Odontologia
# 4                           Administração  Administração   Fonoaudiologia
#
#   TesteVocacionalOnline TesteVocacionalOrg                UNASP
# 0       Biblioteconomia                 TI  Ciências biológicas
# 1      Ciências Sociais         Astronomia           Rádio e TV
# ...

# %%
stella_vocacional.describe()
# Out:
#        MundoVestibular QueroBolsa Neora    G1 FundacaEstudar  \
# count               21         21    21    21             21
# unique              21          7     7    11             18
# top         Astronomia       None  None  None           None
# freq                 1         15    15    11              4
#
#        TesteVocacionalOnline TesteVocacionalOrg UNASP
# count                     21                 21    21
# unique                    10                  8    13
# top                     None               None  None
# freq                      12                 14     9

# %%
Counter(c1).most_common
# Out:
# <bound method Counter.most_common of Counter({'Arquitetura': 1, 'Artes Cênicas': 1, 'Artes plásticas': 1, 'Astronomia': 1, 'Ciências Biológicas (Biologia)': 1, 'Cinema': 1, 'Engenharia Mecânica': 1, 'Esporte': 1, 'Filosofia': 1, 'Jornalismo': 1, 'Matemática': 1, 'Publicidade': 1, 'Rádio e TV': 1, 'Turismo': 1, 'Veterinária': 1, 'Educação Física': 1, 'Meteorologia': 1, 'Oceanografia': 1, 'Engenharia Ambiental': 1, 'Engenharia Florestal': 1, 'Arqueologia': 1})>

# %%
stella_vocacional.columns
# Out:
# Index(['MundoVestibular', 'QueroBolsa', 'Neora', 'G1', 'FundacaEstudar',
#        'TesteVocacionalOnline', 'TesteVocacionalOrg', 'UNASP'],
#       dtype='object')

# %%
listao = MundoVestibular + QueroBolsa + Neora + G1 + FundacaoEstudar + TesteVocacionalOnline + TesteVocacionalOrg + UNASP

# %%
listao
# Out:
# ['Arquitetura',
#  'Artes Cênicas',
#  'Artes plásticas',
#  'Astronomia',
#  'Ciências Biológicas (Biologia)',
#  'Cinema',
#  'Engenharia Mecânica',
#  'Esporte',
#  'Filosofia',
#  'Jornalismo',
#  'Matemática',
#  'Publicidade',
#  'Rádio e TV',
#  'Turismo',
#  'Veterinária',
#  'Educação Física',
#  'Meteorologia',
#  'Oceanografia',
#  'Engenharia Ambiental',
#  'Engenharia Florestal',
#  'Arqueologia',
#  'Gestão Financeira',
#  'Marketing',
#  'Administração',
#  'Direito',
#  'Pedagogia',
#  'Psicologia',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'Gestão pública',
#  'Administração e Organização de eventos',
#  'Gestão hospitalar',
#  'Jornalismo',
#  'Administração',
#  'Gastronomia',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
# ...

# %%
Counter(listao).most_common(6)
# Out:
# [('None', 80),
#  ('Educação Física', 4),
#  ('Pedagogia', 4),
#  ('Psicologia', 4),
#  ('Arquitetura', 3),
#  ('Astronomia', 3)]
